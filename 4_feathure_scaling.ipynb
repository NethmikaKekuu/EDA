# %%
# !pip install -r requirments.txt
# Out:
# Requirement already satisfied: numpy in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 1)) (2.4.2)
# Requirement already satisfied: pandas in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 2)) (3.0.0)
# Requirement already satisfied: scikit-learn in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 3)) (1.8.0)
# Requirement already satisfied: openai in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 4)) (2.21.0)
# Requirement already satisfied: groq in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 5)) (1.0.0)
# Requirement already satisfied: seaborn in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 6)) (0.13.2)
# Requirement already satisfied: dotenv in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 7)) (0.9.9)
# Requirement already satisfied: matplotlib in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from -r requirments.txt (line 8)) (3.10.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from pandas->-r requirments.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from pandas->-r requirments.txt (line 2)) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from scikit-learn->-r requirments.txt (line 3)) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from scikit-learn->-r requirments.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from scikit-learn->-r requirments.txt (line 3)) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from openai->-r requirments.txt (line 4)) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from anyio<5,>=3.5.0->openai->-r requirments.txt (line 4)) (3.11)
# Requirement already satisfied: certifi in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirments.txt (line 4)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirments.txt (line 4)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirments.txt (line 4)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirments.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirments.txt (line 4)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirments.txt (line 4)) (0.4.2)
# Requirement already satisfied: python-dotenv in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from dotenv->-r requirments.txt (line 7)) (1.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from matplotlib->-r requirments.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from matplotlib->-r requirments.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from matplotlib->-r requirments.txt (line 8)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from matplotlib->-r requirments.txt (line 8)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from matplotlib->-r requirments.txt (line 8)) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from matplotlib->-r requirments.txt (line 8)) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from matplotlib->-r requirments.txt (line 8)) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirments.txt (line 2)) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages (from tqdm>4->openai->-r requirments.txt (line 4)) (0.4.6)

# %% [markdown]
# Import Dependencies

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# What is Normalization?
# Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also know as Min-Max scaling. ((x-min)/(max-min))
#
# What is Standardization?
# Standardization is another scaling technique where the values are centred around the mean with a unit standard deviation. This means that the mean of the attribute becomes zero and the resultant distribution has a unit standard deviation. ((x-mean)/sd)

# %% [markdown]
# Basic Processing

# %%
df = pd.read_csv('data/processed/ChurnModelling_Encoded.csv')
df.head(10)
# Out:
#      Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  42.00       2       0.00              1          1               1
# 1  41.00       1   83807.86              1          0               1
# 2  42.00       8  159660.80              3          1               0
# 3  38.91       1       0.00              2          0               0
# 4  43.00       2  125510.82              1          1               1
# 5  44.00       8  113755.78              2          1               0
# 6  50.00       7       0.00              2          1               1
# 7  29.00       4  115046.74              4          1               0
# 8  44.00       4  142051.07              2          0               1
# 9  27.00       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited  CreditScoreBins  Geography_France  \
# 0        101348.88       1                1              True
# 1        112542.58       0                1             False
# 2        113931.57       1                0              True
# 3         93826.63       0                2              True
# 4         79084.10       0                4             False
# 5        149756.71       1                1             False
# 6         10062.80       0                4              True
# 7        119346.88       1                0             False
# 8         74940.50       0                0              True
# 9         71725.73       0                2              True
#
#    Geography_Germany  Geography_Spain  Gender_female  Gender_male
# 0              False            False           True        False
# 1              False             True           True        False
# 2              False            False           True        False
# 3              False            False           True        False
# 4              False             True           True        False
# 5              False             True          False         True
# 6              False            False          False         True
# 7               True            False           True        False
# 8              False            False          False         True
# 9              False            False          False         True

# %% [markdown]
# # Feature Scaling: Min-Max vs Standardization (Z-score)
#
# | Condition                                      |   Min-Max Scaling              | Standardization (Z-score)             |
# |------------------------------------------------|--------------------------------|---------------------------------------|
# | Data has a known, fixed range                  |  Yes                           |  Not ideal                            |
# | Data contains outliers                         |  Sensitive to outliers         |  More robust to outliers              |
# | Data is normally distributed                   |  Not necessary                 |  Preferred                            |
# | Data is not normally distributed (e.g., skewed)|  If shape needs to be preserved|  Often works well after log-transform |
# | Model is distance-based (KNN, SVM)             |  Recommended                   |  Also acceptable                      |
# | Model is neural network                        |  Strongly recommended          |  May slow training                    |
# | Model is linear or uses regularization         |  Not ideal                     |  Helps with convergence               |
# | Input features need bounded values (0–1)       |  Required                      |  Not bounded                          |
# | Applying PCA or LDA                            |  May distort variance          |  Required (centering needed)          |
# | Want to preserve original distribution shape   |  Maintains feature shape       |  Maintains shape but centers data     |
# | Working with tree-based models                 |  Not needed                    |  Not needed                           |

# %%
#These scaling was done using z-score each variable canhave different methods
columns_need_to_be_scaled =['Age','Tenure','Balance','EstimatedSalary']

for col in columns_need_to_be_scaled:
    standard_scaler = StandardScaler()
    df[col] = standard_scaler.fit_transform(df[col].values.reshape(10000,1))

# %%
df.to_csv('data/processed/ChurnModelling_Final.csv', index=False)
